# %% [markdown]
# # JSON data wrangling with python

# %% [markdown]
# Solving the double/multiple nesting problem

# %%
import requests, pandas as pd

# %%
url ='https://api.worldbank.org/v2/country/GBR/indicator/SP.POP.TOTL?format=json'
html = requests.get(url)

# %%
json_data=html.json()

# %% [markdown]
# Creating a `pandas` dataframe

# %%
#create dataframe directly
pd.DataFrame(json_data[1])

# %%
# create array in loop
for i in json_data[1]:
  # print(i)
# Out:
#   File "<ipython-input-13-636286918d17>", line 2
#     # print(i)
#               ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# # Scraping *light*

# %% [markdown]
# Reading from `HTML` tables direclty with `pandas`

# %%
tables=pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(PPP)_per_capita')

# %%
df=tables[1]

# %%
df.columns=['country','subregion','region','IMF','IMFyear','WB','WByear','CIA','CIAyear']

# %% [markdown]
# `pandas` DataFrame sorting

# %%
df.sort_values(by='country')
# Out:
#                  country        subregion   region  ...  WByear      CIA  CIAyear
# 211        Afghanistan *    Southern Asia     Asia  ...  2020.0   2065.0   2019.0
# 116            Albania *  Southern Europe   Europe  ...  2020.0  13965.0   2019.0
# 138            Algeria *  Northern Africa   Africa  ...  2020.0  11511.0   2019.0
# 140     American Samoa *        Polynesia  Oceania  ...     NaN  11200.0   2016.0
# 32             Andorra *  Southern Europe   Europe  ...     NaN  49900.0   2015.0
# ..                   ...              ...      ...  ...     ...      ...      ...
# 187  Wallis and Futuna *        Polynesia  Oceania  ...     NaN   3800.0   2004.0
# 101                World            World    World  ...  2020.0  17500.0   2017.0
# 210              Yemen *     Western Asia     Asia  ...  2013.0   2500.0   2017.0
# 193             Zambia *   Eastern Africa   Africa  ...  2020.0   3470.0   2019.0
# 198           Zimbabwe *   Eastern Africa   Africa  ...  2020.0   2836.0   2019.0
#
# [227 rows x 9 columns]

# %%
df['country'].str.replace('*','')
# Out:
# 0                 Liechtenstein
# 1                    Luxembourg
# 2                        Monaco
# 3                     Singapore
# 4                       Ireland
#                  ...
# 222                      Malawi
# 223                    DR Congo
# 224    Central African Republic
# 225                     Somalia
# 226                     Burundi
# Name: country, Length: 227, dtype: object

# %%
df=df.sort_values(by='country')
df['country']=df['country'].str.replace('*','')

# %%
df.to_csv('my_data.csv')

# %% [markdown]
# # Scraping *level 2*

# %%
url='https://www.comparethemarket.com/car-insurance/content/global-supercar-index/'

# %%
pd.read_html(url)

# %%
from bs4 import BeautifulSoup

# %%
html = requests.get(url)
soup = BeautifulSoup(html.content, 'html.parser')

# %%
table=soup.find('div',id='cheapest-countries')

# %%
headings=table.findAll('h4')

# %%
values=table.findAll('p',class_='lead')
# table.findAll('p',{'class':'lead'})

# %%
headings_list=[i.text for i in headings]

# %%
values_list=[int(i.text.replace('£','').replace(',','')) for i in values]

# %%
df1=pd.DataFrame([headings_list,values_list]).T

# %%
table=soup.find('div',id='expensive-countries')
headings=table.findAll('h4')
values=table.findAll('p',class_='lead')
df2=pd.DataFrame([[i.text for i in headings],
              [int(i.text.replace('£','').replace(',','')) for i in values]]).T

# %%
pd.concat([df1,df2])
# Out:
#                 0       1
# 0          Canada  136703
# 1          Mexico  139930
# 2  United Kingdom  155970
# 0       Argentina  549840
# 1       Singapore  526958
# 2         Vietnam  524620

# %% [markdown]
# # Advanced: scraping with `Selenium` *zombie browser*
